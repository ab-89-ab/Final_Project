# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
import sklearn.metrics
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# conda install -c conda-forge imbalanced-learn

# %%
df=pd.read_csv('~/Downloads/home-credit-default-risk/application_train.csv')

# %%
df['age']= (df['DAYS_BIRTH']/-365).round(0)

# %%
df.columns.tolist()
# Out:
# ['SK_ID_CURR',
#  'TARGET',
#  'NAME_CONTRACT_TYPE',
#  'CODE_GENDER',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'REGION_POPULATION_RELATIVE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_REGISTRATION',
#  'DAYS_ID_PUBLISH',
#  'OWN_CAR_AGE',
#  'FLAG_MOBIL',
#  'FLAG_EMP_PHONE',
#  'FLAG_WORK_PHONE',
#  'FLAG_CONT_MOBILE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'OCCUPATION_TYPE',
#  'CNT_FAM_MEMBERS',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'WEEKDAY_APPR_PROCESS_START',
#  'HOUR_APPR_PROCESS_START',
#  'REG_REGION_NOT_LIVE_REGION',
#  'REG_REGION_NOT_WORK_REGION',
#  'LIVE_REGION_NOT_WORK_REGION',
#  'REG_CITY_NOT_LIVE_CITY',
#  'REG_CITY_NOT_WORK_CITY',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'ORGANIZATION_TYPE',
#  'EXT_SOURCE_1',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_3',
#  'APARTMENTS_AVG',
#  'BASEMENTAREA_AVG',
#  'YEARS_BEGINEXPLUATATION_AVG',
#  'YEARS_BUILD_AVG',
#  'COMMONAREA_AVG',
#  'ELEVATORS_AVG',
#  'ENTRANCES_AVG',
#  'FLOORSMAX_AVG',
#  'FLOORSMIN_AVG',
#  'LANDAREA_AVG',
#  'LIVINGAPARTMENTS_AVG',
#  'LIVINGAREA_AVG',
#  'NONLIVINGAPARTMENTS_AVG',
#  'NONLIVINGAREA_AVG',
#  'APARTMENTS_MODE',
#  'BASEMENTAREA_MODE',
#  'YEARS_BEGINEXPLUATATION_MODE',
#  'YEARS_BUILD_MODE',
#  'COMMONAREA_MODE',
#  'ELEVATORS_MODE',
#  'ENTRANCES_MODE',
#  'FLOORSMAX_MODE',
#  'FLOORSMIN_MODE',
#  'LANDAREA_MODE',
#  'LIVINGAPARTMENTS_MODE',
#  'LIVINGAREA_MODE',
#  'NONLIVINGAPARTMENTS_MODE',
#  'NONLIVINGAREA_MODE',
#  'APARTMENTS_MEDI',
#  'BASEMENTAREA_MEDI',
#  'YEARS_BEGINEXPLUATATION_MEDI',
#  'YEARS_BUILD_MEDI',
#  'COMMONAREA_MEDI',
#  'ELEVATORS_MEDI',
#  'ENTRANCES_MEDI',
#  'FLOORSMAX_MEDI',
#  'FLOORSMIN_MEDI',
#  'LANDAREA_MEDI',
#  'LIVINGAPARTMENTS_MEDI',
#  'LIVINGAREA_MEDI',
#  'NONLIVINGAPARTMENTS_MEDI',
#  'NONLIVINGAREA_MEDI',
#  'FONDKAPREMONT_MODE',
#  'HOUSETYPE_MODE',
#  'TOTALAREA_MODE',
#  'WALLSMATERIAL_MODE',
#  'EMERGENCYSTATE_MODE',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'OBS_60_CNT_SOCIAL_CIRCLE',
#  'DEF_60_CNT_SOCIAL_CIRCLE',
#  'DAYS_LAST_PHONE_CHANGE',
#  'FLAG_DOCUMENT_2',
#  'FLAG_DOCUMENT_3',
#  'FLAG_DOCUMENT_4',
#  'FLAG_DOCUMENT_5',
#  'FLAG_DOCUMENT_6',
#  'FLAG_DOCUMENT_7',
#  'FLAG_DOCUMENT_8',
#  'FLAG_DOCUMENT_9',
#  'FLAG_DOCUMENT_10',
#  'FLAG_DOCUMENT_11',
#  'FLAG_DOCUMENT_12',
#  'FLAG_DOCUMENT_13',
#  'FLAG_DOCUMENT_14',
#  'FLAG_DOCUMENT_15',
#  'FLAG_DOCUMENT_16',
#  'FLAG_DOCUMENT_17',
#  'FLAG_DOCUMENT_18',
#  'FLAG_DOCUMENT_19',
#  'FLAG_DOCUMENT_20',
#  'FLAG_DOCUMENT_21',
#  'AMT_REQ_CREDIT_BUREAU_HOUR',
#  'AMT_REQ_CREDIT_BUREAU_DAY',
#  'AMT_REQ_CREDIT_BUREAU_WEEK',
#  'AMT_REQ_CREDIT_BUREAU_MON',
#  'AMT_REQ_CREDIT_BUREAU_QRT',
#  'AMT_REQ_CREDIT_BUREAU_YEAR',
#  'age']

# %%
df.drop(['NAME_CONTRACT_TYPE','FLAG_OWN_REALTY',
 'CNT_CHILDREN','REGION_POPULATION_RELATIVE',
 'DAYS_EMPLOYED',
 'DAYS_REGISTRATION',
 'DAYS_ID_PUBLISH','OWN_CAR_AGE',
 'FLAG_MOBIL',
 'FLAG_EMP_PHONE',
 'FLAG_WORK_PHONE',
 'FLAG_CONT_MOBILE',
 'FLAG_PHONE',
 'FLAG_EMAIL','CNT_FAM_MEMBERS',
 'REGION_RATING_CLIENT',
 'REGION_RATING_CLIENT_W_CITY',
 'WEEKDAY_APPR_PROCESS_START',
 'HOUR_APPR_PROCESS_START',
 'REG_REGION_NOT_LIVE_REGION',
 'REG_REGION_NOT_WORK_REGION',
 'LIVE_REGION_NOT_WORK_REGION',
 'REG_CITY_NOT_LIVE_CITY',
 'REG_CITY_NOT_WORK_CITY',
 'LIVE_CITY_NOT_WORK_CITY',
 'ORGANIZATION_TYPE',
 'EXT_SOURCE_1',
 'EXT_SOURCE_2',
 'EXT_SOURCE_3',
 'APARTMENTS_AVG',
 'BASEMENTAREA_AVG',
 'YEARS_BEGINEXPLUATATION_AVG',
 'YEARS_BUILD_AVG',
 'COMMONAREA_AVG',
 'ELEVATORS_AVG',
 'ENTRANCES_AVG',
 'FLOORSMAX_AVG',
 'FLOORSMIN_AVG',
 'LANDAREA_AVG',
 'LIVINGAPARTMENTS_AVG',
 'LIVINGAREA_AVG',
 'NONLIVINGAPARTMENTS_AVG',
 'NONLIVINGAREA_AVG',
 'APARTMENTS_MODE',
 'BASEMENTAREA_MODE',
 'YEARS_BEGINEXPLUATATION_MODE',
 'YEARS_BUILD_MODE',
 'COMMONAREA_MODE',
 'ELEVATORS_MODE',
 'ENTRANCES_MODE',
 'FLOORSMAX_MODE',
 'FLOORSMIN_MODE',
 'LANDAREA_MODE',
 'LIVINGAPARTMENTS_MODE',
 'LIVINGAREA_MODE',
 'NONLIVINGAPARTMENTS_MODE',
 'NONLIVINGAREA_MODE',
 'APARTMENTS_MEDI',
 'BASEMENTAREA_MEDI',
 'YEARS_BEGINEXPLUATATION_MEDI',
 'YEARS_BUILD_MEDI',
 'COMMONAREA_MEDI',
 'ELEVATORS_MEDI',
 'ENTRANCES_MEDI',
 'FLOORSMAX_MEDI',
 'FLOORSMIN_MEDI',
 'LANDAREA_MEDI',
 'LIVINGAPARTMENTS_MEDI',
 'LIVINGAREA_MEDI',
 'NONLIVINGAPARTMENTS_MEDI',
 'NONLIVINGAREA_MEDI',
 'FONDKAPREMONT_MODE',
 'HOUSETYPE_MODE',
 'TOTALAREA_MODE',
 'WALLSMATERIAL_MODE',
 'EMERGENCYSTATE_MODE',
 'OBS_30_CNT_SOCIAL_CIRCLE',
 'DEF_30_CNT_SOCIAL_CIRCLE',
 'OBS_60_CNT_SOCIAL_CIRCLE',
 'DEF_60_CNT_SOCIAL_CIRCLE',
 'DAYS_LAST_PHONE_CHANGE',
 'FLAG_DOCUMENT_2',
 'FLAG_DOCUMENT_3',
 'FLAG_DOCUMENT_4',
 'FLAG_DOCUMENT_5',
 'FLAG_DOCUMENT_6',
 'FLAG_DOCUMENT_7',
 'FLAG_DOCUMENT_8',
 'FLAG_DOCUMENT_9',
 'FLAG_DOCUMENT_10',
 'FLAG_DOCUMENT_11',
 'FLAG_DOCUMENT_12',
 'FLAG_DOCUMENT_13',
 'FLAG_DOCUMENT_14',
 'FLAG_DOCUMENT_15',
 'FLAG_DOCUMENT_16',
 'FLAG_DOCUMENT_17',
 'FLAG_DOCUMENT_18',
 'FLAG_DOCUMENT_19',
 'FLAG_DOCUMENT_20',
 'FLAG_DOCUMENT_21',
 'AMT_REQ_CREDIT_BUREAU_HOUR',
 'AMT_REQ_CREDIT_BUREAU_DAY',
 'AMT_REQ_CREDIT_BUREAU_WEEK',
 'AMT_REQ_CREDIT_BUREAU_MON',
 'AMT_REQ_CREDIT_BUREAU_QRT',
 'AMT_REQ_CREDIT_BUREAU_YEAR','OCCUPATION_TYPE','NAME_FAMILY_STATUS','NAME_TYPE_SUITE','AMT_CREDIT','AMT_ANNUITY','AMT_GOODS_PRICE','DAYS_BIRTH'
        ], axis = 1, inplace=True)

# %%
df[df['CODE_GENDER']=='XNA']
df.drop(df.index[[35657,38566,83382,189640]],inplace=True)

# %%
from imblearn.over_sampling import SMOTE

# %%
df.head(15)
# Out:
#     SK_ID_CURR  TARGET CODE_GENDER FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 0       100002       1           M            N        202500.000
# 1       100003       0           F            N        270000.000
# 2       100004       0           M            Y         67500.000
# 3       100006       0           F            N        135000.000
# 4       100007       0           M            N        121500.000
# 5       100008       0           M            N         99000.000
# 6       100009       0           F            Y        171000.000
# 7       100010       0           M            Y        360000.000
# 8       100011       0           F            N        112500.000
# 9       100012       0           M            N        135000.000
# 10      100014       0           F            N        112500.000
# 11      100015       0           F            N         38419.155
# 12      100016       0           F            N         67500.000
# 13      100017       0           M            Y        225000.000
# 14      100018       0           F            N        189000.000
#
#         NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  \
# 0                Working  Secondary / secondary special  House / apartment
# 1          State servant               Higher education  House / apartment
# 2                Working  Secondary / secondary special  House / apartment
# 3                Working  Secondary / secondary special  House / apartment
# 4                Working  Secondary / secondary special  House / apartment
# 5          State servant  Secondary / secondary special  House / apartment
# 6   Commercial associate               Higher education  House / apartment
# 7          State servant               Higher education  House / apartment
# 8              Pensioner  Secondary / secondary special  House / apartment
# 9                Working  Secondary / secondary special  House / apartment
# 10               Working               Higher education  House / apartment
# 11             Pensioner  Secondary / secondary special  House / apartment
# 12               Working  Secondary / secondary special  House / apartment
# 13               Working  Secondary / secondary special  House / apartment
# 14               Working  Secondary / secondary special  House / apartment
#
#      age
# 0   26.0
# 1   46.0
# 2   52.0
# 3   52.0
# 4   55.0
# 5   46.0
# 6   38.0
# 7   52.0
# 8   55.0
# 9   40.0
# 10  28.0
# 11  56.0
# 12  37.0
# 13  39.0
# 14  40.0

# %%
df.tail(50)
# Out:
#         SK_ID_CURR  TARGET CODE_GENDER FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 307461      456200       0           F            N          157500.0
# 307462      456201       0           F            Y          135000.0
# 307463      456203       0           F            N          180000.0
# 307464      456204       0           F            N           58500.0
# 307465      456205       0           F            N          180000.0
# 307466      456206       0           F            N          157500.0
# 307467      456207       0           F            N          247500.0
# 307468      456208       0           F            N          135000.0
# 307469      456209       0           F            N          202500.0
# 307470      456210       0           F            N           90000.0
# 307471      456211       0           F            N          112500.0
# 307472      456212       0           F            N          135000.0
# 307473      456213       0           F            Y           90000.0
# 307474      456214       0           M            Y          135000.0
# 307475      456215       1           F            N          144000.0
# 307476      456216       0           F            N          135000.0
# 307477      456217       0           F            N          360000.0
# 307478      456218       0           F            N          225000.0
# 307479      456219       0           F            N          112500.0
# 307480      456220       0           F            N           81000.0
# 307481      456225       1           M            N          225000.0
# 307482      456226       0           F            Y          225000.0
# 307483      456227       0           F            N           99000.0
# 307484      456228       0           F            Y          540000.0
# 307485      456229       0           F            N          270000.0
# 307486      456230       0           F            Y          292500.0
# 307487      456231       0           M            N          117000.0
# 307488      456232       0           F            N          157500.0
# 307489      456233       1           F            N          225000.0
# 307490      456234       0           M            N           81000.0
# 307491      456235       0           M            Y           90000.0
# 307492      456236       0           M            Y          585000.0
# 307493      456237       0           F            N          135000.0
# 307494      456238       0           M            Y          270000.0
# 307495      456239       0           M            Y          180000.0
# 307496      456240       0           F            N          360000.0
# 307497      456241       0           F            Y          180000.0
# 307498      456242       0           M            Y          198000.0
# 307499      456243       0           F            N           81000.0
# 307500      456244       0           F            N          261000.0
# 307501      456245       0           F            N           81000.0
# 307502      456246       0           F            N           94500.0
# 307503      456247       0           F            N          112500.0
# 307504      456248       0           F            N          153000.0
# 307505      456249       0           F            N          112500.0
# 307506      456251       0           M            N          157500.0
# 307507      456252       0           F            N           72000.0
# 307508      456253       0           F            N          153000.0
# 307509      456254       1           F            N          171000.0
# 307510      456255       0           F            N          157500.0
#
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 307461               Working               Higher education
# 307462               Working  Secondary / secondary special
# 307463             Pensioner  Secondary / secondary special
# 307464         State servant  Secondary / secondary special
# 307465               Working  Secondary / secondary special
# 307466         State servant  Secondary / secondary special
# 307467               Working               Higher education
# 307468               Working               Higher education
# 307469             Pensioner  Secondary / secondary special
# 307470               Working  Secondary / secondary special
# 307471               Working  Secondary / secondary special
# 307472  Commercial associate               Higher education
# 307473               Working  Secondary / secondary special
# 307474  Commercial associate  Secondary / secondary special
# 307475               Working               Higher education
# 307476               Working               Higher education
# 307477         State servant               Higher education
# 307478  Commercial associate               Higher education
# 307479               Working  Secondary / secondary special
# 307480         State servant               Higher education
# 307481               Working  Secondary / secondary special
# 307482  Commercial associate  Secondary / secondary special
# 307483             Pensioner  Secondary / secondary special
# 307484  Commercial associate  Secondary / secondary special
# 307485               Working  Secondary / secondary special
# 307486  Commercial associate               Higher education
# 307487             Pensioner  Secondary / secondary special
# 307488         State servant               Higher education
# 307489  Commercial associate  Secondary / secondary special
# 307490  Commercial associate               Higher education
# 307491  Commercial associate  Secondary / secondary special
# 307492               Working  Secondary / secondary special
# 307493               Working  Secondary / secondary special
# 307494  Commercial associate  Secondary / secondary special
# 307495               Working               Higher education
# 307496               Working               Higher education
# 307497               Working  Secondary / secondary special
# 307498  Commercial associate  Secondary / secondary special
# 307499  Commercial associate  Secondary / secondary special
# 307500               Working               Higher education
# 307501  Commercial associate  Secondary / secondary special
# 307502               Working  Secondary / secondary special
# 307503  Commercial associate               Higher education
# 307504               Working  Secondary / secondary special
# 307505             Pensioner  Secondary / secondary special
# 307506               Working  Secondary / secondary special
# 307507             Pensioner  Secondary / secondary special
# 307508               Working               Higher education
# 307509  Commercial associate  Secondary / secondary special
# 307510  Commercial associate               Higher education
#
#         NAME_HOUSING_TYPE   age
# 307461  House / apartment  35.0
# 307462  House / apartment  34.0
# 307463  House / apartment  66.0
# 307464  House / apartment  40.0
# 307465  House / apartment  37.0
# 307466  House / apartment  47.0
# 307467  House / apartment  49.0
# 307468  House / apartment  27.0
# 307469  House / apartment  61.0
# 307470  House / apartment  29.0
# 307471  House / apartment  37.0
# 307472  House / apartment  49.0
# 307473  House / apartment  40.0
# 307474       With parents  48.0
# 307475  House / apartment  37.0
# 307476  House / apartment  38.0
# 307477  House / apartment  51.0
# 307478  House / apartment  53.0
# 307479  House / apartment  37.0
# 307480   Rented apartment  29.0
# 307481  House / apartment  57.0
# 307482  House / apartment  39.0
# 307483  House / apartment  68.0
# 307484   Rented apartment  35.0
# 307485       With parents  33.0
# 307486  House / apartment  44.0
# 307487  House / apartment  63.0
# 307488  House / apartment  28.0
# 307489  House / apartment  45.0
# 307490  House / apartment  27.0
# 307491  House / apartment  30.0
# 307492  House / apartment  57.0
# 307493  House / apartment  48.0
# 307494  House / apartment  41.0
# 307495  House / apartment  57.0
# 307496  House / apartment  48.0
# 307497  House / apartment  46.0
# 307498  House / apartment  52.0
# 307499  House / apartment  47.0
# 307500  House / apartment  56.0
# 307501  House / apartment  36.0
# 307502  House / apartment  44.0
# 307503  House / apartment  33.0
# 307504  House / apartment  46.0
# 307505  House / apartment  67.0
# 307506       With parents  26.0
# 307507  House / apartment  57.0
# 307508  House / apartment  41.0
# 307509  House / apartment  33.0
# 307510  House / apartment  46.0

# %%
df[158:162]
# Out:
#      SK_ID_CURR  TARGET CODE_GENDER FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 158      100186       0           F            N          117000.0
# 159      100188       0           F            N          225000.0
# 160      100189       0           F            N          135000.0
# 161      100190       0           M            Y          162000.0
#
#          NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  \
# 158             Pensioner  Secondary / secondary special  House / apartment
# 159               Working               Higher education   Office apartment
# 160               Working              Incomplete higher  House / apartment
# 161  Commercial associate               Higher education  House / apartment
#
#       age
# 158  60.0
# 159  42.0
# 160  46.0
# 161  38.0

# %%
df[493:496]
# Out:
#      SK_ID_CURR  TARGET CODE_GENDER FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 493      100570       0           F            Y          180000.0
# 494      100571       0           M            Y          292500.0
# 495      100572       0           F            N           31500.0
#
#          NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE  \
# 493  Commercial associate  Secondary / secondary special  House / apartment
# 494               Working  Secondary / secondary special  House / apartment
# 495             Pensioner                Lower secondary  House / apartment
#
#       age
# 493  36.0
# 494  27.0
# 495  52.0

# %%
df[2140:2143]
# Out:
#       SK_ID_CURR  TARGET CODE_GENDER FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 2140      102514       0           F            N          112500.0
# 2141      102515       0           F            Y          130500.0
# 2142      102516       0           F            N          121500.0
#
#      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE   age
# 2140          Working  Secondary / secondary special  House / apartment  33.0
# 2141    State servant                Academic degree  House / apartment  40.0
# 2142        Pensioner  Secondary / secondary special  House / apartment  58.0

# %%
df[222:224]
# Out:
#      SK_ID_CURR  TARGET CODE_GENDER FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 222      100259       0           M            Y          180000.0
# 223      100260       0           M            N          180000.0
#
#     NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE   age
# 222        Pensioner  Secondary / secondary special  House / apartment  57.0
# 223          Working               Higher education    Co-op apartment  28.0

# %%
df[df['NAME_HOUSING_TYPE']=='Municipal apartment']
# Out:
#         SK_ID_CURR  TARGET CODE_GENDER FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 56          100064       0           F            N           67500.0
# 67          100079       0           M            N          225000.0
# 130         100152       0           F            N          157500.0
# 144         100166       0           F            N           58500.0
# 147         100174       0           F            N          180000.0
# ...            ...     ...         ...          ...               ...
# 307312      456036       0           M            Y          270000.0
# 307349      456074       0           M            Y          315000.0
# 307394      456127       0           M            N          157500.0
# 307433      456171       1           M            N           50400.0
# 307450      456188       0           F            N           54000.0
#
#        NAME_INCOME_TYPE            NAME_EDUCATION_TYPE    NAME_HOUSING_TYPE  \
# 56            Pensioner  Secondary / secondary special  Municipal apartment
# 67              Working  Secondary / secondary special  Municipal apartment
# 130             Working  Secondary / secondary special  Municipal apartment
# 144             Working  Secondary / secondary special  Municipal apartment
# 147             Working              Incomplete higher  Municipal apartment
# ...                 ...                            ...                  ...
# 307312          Working               Higher education  Municipal apartment
# 307349          Working  Secondary / secondary special  Municipal apartment
# 307394          Working  Secondary / secondary special  Municipal apartment
# 307433        Pensioner                Lower secondary  Municipal apartment
# 307450        Pensioner  Secondary / secondary special  Municipal apartment
#
#          age
# 56      59.0
# 67      42.0
# 130     44.0
# 144     39.0
# 147     40.0
# ...      ...
# 307312  37.0
# 307349  55.0
# 307394  38.0
# 307433  30.0
# 307450  56.0
#
# [11182 rows x 9 columns]

# %%
df['NAME_HOUSING_TYPE'].unique()
# Out:
# array([1, 4, 5, 2, 3, 0], dtype=int8)

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

# %%
y=df.loc[:,df.columns=='TARGET']
X=df.loc[:,['CODE_GENDER','FLAG_OWN_CAR','AMT_INCOME_TOTAL','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_HOUSING_TYPE','age']]

# %%
from imblearn.over_sampling import SMOTE

# %%
os = SMOTE(random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
columns = X_train.columns

# %%
# y_train.info()

# %%
os_data_X,os_data_y=os.fit_sample(X_train, y_train)
os_data_X = pd.DataFrame(data=os_data_X,columns=columns )
os_data_y= pd.DataFrame(data=os_data_y,columns=['TARGET'])
# we can Check the numbers of our data
print("length of oversampled data is ",len(os_data_X))
print("NUMBER OF GOOD LOANS",len(os_data_y[os_data_y['TARGET']==0]))
print("NUMBER OF DEFAULTS",len(os_data_y[os_data_y['TARGET']==1]))
print("Proportion of GOOD LOANS data in oversampled data is ",len(os_data_y[os_data_y['TARGET']==0])/len(os_data_X))
print("Proportion of DEFAULTS data in oversampled data is ",len(os_data_y[os_data_y['TARGET']==1])/len(os_data_X))
# Out:
# length of oversampled data is  395724
# NUMBER OF GOOD LOANS 197862
# NUMBER OF DEFAULTS 197862
# Proportion of GOOD LOANS data in oversampled data is  0.5
# Proportion of DEFAULTS data in oversampled data is  0.5

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(os_data_X[: 250000], os_data_y.values.ravel()[:250000])
# Out:
# LogisticRegression()

# %%
# y_pred = logreg.predict(os_data_X[250000:])
# print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))

# %%
len(y_test)
# Out:
# 92253

# %%
# from sklearn.metrics import confusion_matrix
# confusion_matrix = confusion_matrix(y_test[250000:], y_pred)
# print(confusion_matrix)

# %%
import statsmodels.api as sm
logit_model=sm.Logit(os_data_y, os_data_X,)
result=logit_model.fit()
result.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.660297
#          Iterations 5
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                            Results: Logit
# =====================================================================
# Model:               Logit             Pseudo R-squared:  0.047
# Dependent Variable:  TARGET            AIC:               522604.7384
# Date:                2020-09-28 21:55  BIC:               522680.9577
# No. Observations:    395724            Log-Likelihood:    -2.6130e+05
# Df Model:            6                 LL-Null:           -2.7429e+05
# Df Residuals:        395717            LLR p-value:       0.0000
# Converged:           1.0000            Scale:             1.0000
# No. Iterations:      5.0000
# ---------------------------------------------------------------------
#                      Coef.  Std.Err.     z     P>|z|   [0.025  0.975]
# ---------------------------------------------------------------------
# CODE_GENDER          0.0589   0.0077    7.6906 0.0000  0.0439  0.0740
# FLAG_OWN_CAR        -0.8524   0.0081 -104.7227 0.0000 -0.8683 -0.8364
# AMT_INCOME_TOTAL     0.0000   0.0000   26.4467 0.0000  0.0000  0.0000
# NAME_INCOME_TYPE     0.0589   0.0012   48.5526 0.0000  0.0565  0.0612
# NAME_EDUCATION_TYPE  0.2144   0.0026   82.4392 0.0000  0.2093  0.2195
# NAME_HOUSING_TYPE   -0.0047   0.0032   -1.4543 0.1459 -0.0110  0.0016
# age                 -0.0223   0.0002 -102.0794 0.0000 -0.0228 -0.0219
# =====================================================================
#
# """

# %%
result.pred_table()
# Out:
# array([[120670.,  77192.],
#        [ 80603., 117259.]])

# %%
y_pred=result.predict(X_test)

# %%
y_pred
# Out:
# 289126    0.553278
# 188491    0.578500
# 181177    0.449067
# 247950    0.522569
# 231639    0.607324
#             ...
# 287907    0.410943
# 125584    0.512295
# 51502     0.288933
# 276439    0.615005
# 115235    0.500252
# Length: 92253, dtype: float64

# %%
y_prediction_test = np.round(y_pred)
y_prediction_test
# Out:
# 289126    1.0
# 188491    1.0
# 181177    0.0
# 247950    1.0
# 231639    1.0
#          ...
# 287907    0.0
# 125584    1.0
# 51502     0.0
# 276439    1.0
# 115235    1.0
# Length: 92253, dtype: float64

# %%
y_test['TARGET']
# Out:
# 289126    0
# 188491    0
# 181177    0
# 247950    0
# 231639    0
#          ..
# 287907    0
# 125584    0
# 51502     0
# 276439    0
# 115235    0
# Name: TARGET, Length: 92253, dtype: int64

# %%
accuracy_score(y_test['TARGET'], y_prediction_test).round(2)
# Out:
# 0.6

# %%
Xnew = [[1,0,167000,7,1,1,30]]

# %%
X_train.head(1)
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  AMT_INCOME_TOTAL  NAME_INCOME_TYPE  \
# 113008            1             1          202500.0                 7
#
#         NAME_EDUCATION_TYPE  NAME_HOUSING_TYPE   age
# 113008                    1                  1  60.0

# %%
ynew = logreg.predict_proba(Xnew)
ynew.round(2)
# Out:
# array([[0.72, 0.28]])

# %%
Xnew1=[[1,0,300000,7,1,1,50]]

# %%
ynew1 = logreg.predict_proba(Xnew1)
ynew1.round(2)
# Out:
# array([[0.83, 0.17]])

# %%
round(ynew1[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-2d468d111787> in <module>
# ----> 1 round(ynew1[0])
#
# TypeError: type numpy.ndarray doesn't define __round__ method

# %%
ynew1[0]
# Out:
# array([0.83436389, 0.16563611])

# %%
ynew1[0][0]
# Out:
# 0.8343638887354852

# %%
round(ynew1[0][0])
# Out:
# 1.0
